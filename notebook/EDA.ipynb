# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
from geodatasets import get_path
from function_06 import load_data_with_delimiters
from shapely.geometry import Point
import folium
from folium.plugins import HeatMap
import re
import pyproj
from folium.plugins import MarkerCluster

# %%
file_info = [
    ("../data/cleaned/df_wea.csv", ','),    
    ("../data/cleaned/gdf_joined.csv", ','),
    ("../data/cleaned/df_ams_cc.csv", ',')

]

dfs = load_data_with_delimiters(file_info)

df_weather = dfs[0]
df_accidents = dfs[1]
df_ams_cc= dfs[2]
display(df_weather.head())
display(df_accidents.head())
display(df_ams_cc.head())
# Out:
#    Unnamed: 0        date  temp_C  precip_mm  wind_avg_ms  sun_hours  \
# 0       24107  2017-01-01     1.6        0.6          5.3        0.0
# 1       24108  2017-01-02     3.2        2.0          3.3        4.6
# 2       24109  2017-01-03     5.7        0.4          7.2        0.7
# 3       24110  2017-01-04     5.9        0.6          8.0        2.8
# 4       24111  2017-01-05     0.3       -0.1          3.0        6.2
#
#    humidity_pct  visibility_min_m  visibility_max_m
# 0          97.0             200.0            3800.0
# 1          83.0            2800.0           32000.0
# 2          85.0           11000.0           25000.0
# 3          76.0            3900.0           22000.0
# 4          79.0           15000.0           47000.0
#    Unnamed: 0  accident_id  total_accidents  fatal_accidents  \
# 0           0            1                1                0
# 1           1            2                1                0
# 2           2            3                1                0
# 3           3            4                1                0
# 4           4            5                2                0
#
#    injury_accidents  damage_only_accidents  \
# 0                 1                      0
# 1                 0                      1
# 2                 0                      1
# 3                 1                      0
# 4                 2                      0
#
#                                         geometry_wkt  \
# 0  POLYGON ((179046.73279999942 309408.8781999983...
# 1  POLYGON ((177255.8396999985 310240.2259999998,...
# 2  POLYGON ((178901.10350000113 311532.4411999993...
# 3  POLYGON ((178656.49430000037 313910.4211000018...
# 4  POLYGON ((176617.4726999998 313949.6506000012,...
#
#                                             geometry  \
# 0  POLYGON ((5.728085069118202 50.77410669272724,...
# 1  POLYGON ((5.702748546852566 50.78165155046857,...
# 2  POLYGON ((5.72616005741394 50.79320068551851, ...
# 3  POLYGON ((5.722845762480663 50.8145856106313, ...
# 4  POLYGON ((5.693918115118937 50.81501866838283,...
#
#                                       centroid  index_right  ...  \
# 0  POINT (179040.2349995231 309458.4569960681)          131  ...
# 1  POINT (177249.3590014013 310289.8069981025)          131  ...
# 2  POINT (178894.6069976456 311582.0199980425)          131  ...
# 3             POINT (178649.9999999999 313960)          131  ...
# 4         POINT (176610.9979999998 313999.232)          131  ...
#
#    weekday_2020  weekday_2019  weekday_2018  weekday_2017  location_code  \
# 0           633             0           830             0     VRA01_0155
# 1           633             0           830             0     VRA01_0155
# 2           633             0           830             0     VRA01_0155
# 3           633             0           830             0     VRA01_0155
# 4           633             0           830             0     VRA01_0155
#
#                  wkt_lng_lat                wkt_lat_lng  longitude   latitude  \
# 0  POINT(5.164806 52.252951)  POINT(52.252951 5.164806)   5.164806  52.252951
# 1  POINT(5.164806 52.252951)  POINT(52.252951 5.164806)   5.164806  52.252951
# 2  POINT(5.164806 52.252951)  POINT(52.252951 5.164806)   5.164806  52.252951
# 3  POINT(5.164806 52.252951)  POINT(52.252951 5.164806)   5.164806  52.252951
# 4  POINT(5.164806 52.252951)  POINT(52.252951 5.164806)   5.164806  52.252951
#
#       distance_m
# 0  169007.617336
# 1  167790.579361
# 2  166908.586421
# 3  164539.720943
# 4  164032.344449
#
# [5 rows x 24 columns]
#    Unnamed: 0  participant_id  accident_id  accident_year  roadsegment_id  \
# 0           0             NaN  20140010399         2014.0     244380021.0
# 1           1             NaN  20140011623         2014.0     242372014.0
# 2           2             NaN  20140011930         2014.0     253372001.0
# 3           3             NaN  20140014189         2014.0     241378037.0
# 4           4             NaN  20140014197         2014.0     233376127.0
#
#   municipality  roadsegment_id.1    segment_startdate      segment_enddate  \
# 0    Amsterdam       244380021.0  2020-12-01T00:00:00  2024-05-31T00:00:00
# 1    Amsterdam       242372014.0  2020-12-01T00:00:00  2024-05-31T00:00:00
# 2    Amsterdam       253372001.0  2021-10-01T00:00:00                  NaN
# 3    Amsterdam       241378037.0  2020-05-01T00:00:00  2021-12-31T00:00:00
# 4    Amsterdam       233376127.0  2020-12-01T00:00:00  2024-05-31T00:00:00
#
#   roadnumber         streetname neighborhood municipality.1  \
# 0        NaN       Klaprozenweg    Amsterdam      Amsterdam
# 1        NaN       Vijzelstraat    Amsterdam      Amsterdam
# 2        010       Ringweg-Oost    Amsterdam      Amsterdam
# 3        NaN       Tasmanstraat    Amsterdam      Amsterdam
# 4        NaN  Burg De Vlugtlaan    Amsterdam      Amsterdam
#
#                                                shape         rd_x  \
# 0  LINESTRING (122469.24489999935 490087.15410000...  122469.2449
# 1  LINESTRING (121256.4354000017 486163.425799999...  121256.4354
# 2  LINESTRING (126588.02679999918 486233.7511, 12...  126588.0268
# 3  LINESTRING (120583.93600000069 489379.40599999...  120583.9360
# 4  LINESTRING (116948.81799999997 488192.20080000...  116948.8180
#
#           rd_y  longitude   latitude
# 0  490087.1541   4.909244  52.397660
# 1  486163.4258   4.891820  52.362323
# 2  486233.7511   4.970084  52.363257
# 3  489379.4060   4.881618  52.391185
# 4  488192.2008   4.828353  52.380275

# %%
#GeoDataFrame uses WGS84 (lat/lon)
gdf_accidents = gpd.GeoDataFrame(df_accidents, 
                                  geometry=gpd.points_from_xy(df_accidents.longitude, df_accidents.latitude),
                                  crs="EPSG:4326")

# %%
# Create base map
m = folium.Map(location=[52.3702, 4.8952], zoom_start=12)  # Amsterdam

# %%
for _, row in gdf_accidents.iterrows():
    folium.CircleMarker(
        location=[row.geometry.y, row.geometry.x],
        radius=3,
        color="red",
        fill=True,
        fill_opacity=0.5
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d8f9e2b0509c7d11e43d7113483e616 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d8f9e2b0509c7d11e43d7113483e616&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d8f9e2b0509c7d11e43d7113483e616 = L.map(
#                 &quot;map_6d8f9e2b0509c7d11e43d7113483e616&quot;,
#                 {
#                     center: [52.3702, 4.8952],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b223aee2ae16b82937be1b01184cf886 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b223aee2ae16b82937be1b01184cf886.addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_cc1afaab3befac8ea74f41f748dce337 = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_7f09125b43c3567967e6acec8f96a70f = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_80c79f214e4f4ee42e50379e3aaccf4c = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_dd5515e3b03710df99bc77af6d93c381 = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_4c57512b2af28ba933e09d638b5f9e44 = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_a35fa2cff8a2ba6e2b0d0dd37c75b41f = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;:

# %%
# Group by location
hotspots = gdf_accidents.groupby(["latitude", "longitude"]).size().reset_index(name="count")
top_hotspots = hotspots.nlargest(20, "count")

# Add to map
for _, row in top_hotspots.iterrows():
    folium.CircleMarker(
        location=[row.latitude, row.longitude],
        radius=row["count"],  # bigger circle for more accidents
        color="darkred",
        fill=True,
        fill_opacity=0.6,
        popup=f"{row['count']} accidents"
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d8f9e2b0509c7d11e43d7113483e616 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d8f9e2b0509c7d11e43d7113483e616&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d8f9e2b0509c7d11e43d7113483e616 = L.map(
#                 &quot;map_6d8f9e2b0509c7d11e43d7113483e616&quot;,
#                 {
#                     center: [52.3702, 4.8952],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b223aee2ae16b82937be1b01184cf886 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b223aee2ae16b82937be1b01184cf886.addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_cc1afaab3befac8ea74f41f748dce337 = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_7f09125b43c3567967e6acec8f96a70f = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_80c79f214e4f4ee42e50379e3aaccf4c = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_dd5515e3b03710df99bc77af6d93c381 = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_4c57512b2af28ba933e09d638b5f9e44 = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6d8f9e2b0509c7d11e43d7113483e616);
#
#
#             var circle_marker_a35fa2cff8a2ba6e2b0d0dd37c75b41f = L.circleMarker(
#                 [52.252951, 5.164806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;:

# %%
#Accident density Heatmap
# Initialize a folium map centered around average location
m = folium.Map(location=[ gdf_accidents.latitude.mean(),  gdf_accidents.longitude.mean()], zoom_start=11, tiles='CartoDB positron')

# Prepare heatmap data
heat_data = [[row['latitude'], row['longitude']] for index, row in  gdf_accidents.iterrows()]

# Add heatmap layer
HeatMap(heat_data, radius=10, blur=15, max_zoom=1).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c0f7804e03a3550671123f6c4021b2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c0f7804e03a3550671123f6c4021b2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c0f7804e03a3550671123f6c4021b2c = L.map(
#                 &quot;map_5c0f7804e03a3550671123f6c4021b2c&quot;,
#                 {
#                     center: [52.31413511259014, 4.943928721575152],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fde069f732ccd67a2156a9eac2b7d89 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8fde069f732ccd67a2156a9eac2b7d89.addTo(map_5c0f7804e03a3550671123f6c4021b2c);
#
#
#             var heat_map_04da4c66957a98abfe59462b6d72e621 = L.heatLayer(
#                 [[52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.25302, 5.16516], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.25302, 5.16516], [52.25302, 5.16516], [52.252951, 5.164806], [52.25302, 5.16516], [52.252951, 5.164806], [52.25302, 5.16516], [52.252951, 5.164806], [52.252951, 5.164806], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.252951, 5.164806], [52.252951, 5.164806], [52.25302, 5.16516], [52.252951, 5.164806], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.252951, 5.164806], [52.25302, 5.16516], [52.25302, 5.16516], [52.252951, 5.164806], [52.25302, 5.16516], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.252951, 5.164806], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.252951, 5.164806], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.252951, 5.164806], [52.254876, 4.57256], [52.25302, 5.16516], [52.252951, 5.164806], [52.252951, 5.164806], [52.25302, 5.16516], [52.25302, 5.16516], [52.254876, 4.57256], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.254876, 4.57256], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.252951, 5.164806], [52.25302, 5.16516], [52.254876, 4.57256], [52.252951, 5.164806], [52.25302, 5.16516], [52.25302, 5.16516], [52.254876, 4.57256], [52.25302, 5.16516], [52.254876, 4.57256], [52.25302, 5.16516], [52.25302, 5.16516], [52.254876, 4.57256], [52.25302, 5.16516], [52.254876, 4.57256], [52.252951, 5.164806], [52.254876, 4.57256], [52.252951, 5.164806], [52.252951, 5.164806], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.254876, 4.57256], [52.254876, 4.57256], [52.254876, 4.57256], [52.254876, 4.57256], [52.252951, 5.164806], [52.254876, 4.57256], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.25302, 5.16516], [52.254876, 4.57256], [52.252951,

# %%
#Accident Severity Distribution
severity_df= pd.DataFrame({
    'Fatal': gdf_accidents['fatal_accidents'],
    'Injury': gdf_accidents['injury_accidents'],
    'Damage Only': gdf_accidents['damage_only_accidents']
}).sum()
# Create a vibrant dark green palette
green_palette = sns.dark_palette("#008000", n_colors=3)

# Plot with transparent background and matching text color
plt.figure(figsize=(8, 5), facecolor='none')
ax = severity_df.plot(kind='bar', color=green_palette)

# Style adjustments
plt.title('Distribution of Accident Severity', fontsize=14, color='#008000')
plt.ylabel('Number of Accidents', color='#008000')
plt.xticks(rotation=0, color='#008000')
plt.yticks(color='#008000')
plt.grid(False)
plt.gca().set_facecolor('none')  # Transparent plot background
plt.tight_layout()
plt.show()

# %%
#Relation between bike traffic volume and accident count
gdf_accidents.head()
# Out:
#    Unnamed: 0  accident_id  total_accidents  fatal_accidents  \
# 0           0            1                1                0
# 1           1            2                1                0
# 2           2            3                1                0
# 3           3            4                1                0
# 4           4            5                2                0
#
#    injury_accidents  damage_only_accidents  \
# 0                 1                      0
# 1                 0                      1
# 2                 0                      1
# 3                 1                      0
# 4                 2                      0
#
#                                         geometry_wkt  \
# 0  POLYGON ((179046.73279999942 309408.8781999983...
# 1  POLYGON ((177255.8396999985 310240.2259999998,...
# 2  POLYGON ((178901.10350000113 311532.4411999993...
# 3  POLYGON ((178656.49430000037 313910.4211000018...
# 4  POLYGON ((176617.4726999998 313949.6506000012,...
#
#                    geometry                                     centroid  \
# 0  POINT (5.16481 52.25295)  POINT (179040.2349995231 309458.4569960681)
# 1  POINT (5.16481 52.25295)  POINT (177249.3590014013 310289.8069981025)
# 2  POINT (5.16481 52.25295)  POINT (178894.6069976456 311582.0199980425)
# 3  POINT (5.16481 52.25295)             POINT (178649.9999999999 313960)
# 4  POINT (5.16481 52.25295)         POINT (176610.9979999998 313999.232)
#
#    index_right  ...  weekday_2020  weekday_2019  weekday_2018  weekday_2017  \
# 0          131  ...           633             0           830             0
# 1          131  ...           633             0           830             0
# 2          131  ...           633             0           830             0
# 3          131  ...           633             0           830             0
# 4          131  ...           633             0           830             0
#
#    location_code                wkt_lng_lat                wkt_lat_lng  \
# 0     VRA01_0155  POINT(5.164806 52.252951)  POINT(52.252951 5.164806)
# 1     VRA01_0155  POINT(5.164806 52.252951)  POINT(52.252951 5.164806)
# 2     VRA01_0155  POINT(5.164806 52.252951)  POINT(52.252951 5.164806)
# 3     VRA01_0155  POINT(5.164806 52.252951)  POINT(52.252951 5.164806)
# 4     VRA01_0155  POINT(5.164806 52.252951)  POINT(52.252951 5.164806)
#
#    longitude   latitude     distance_m
# 0   5.164806  52.252951  169007.617336
# 1   5.164806  52.252951  167790.579361
# 2   5.164806  52.252951  166908.586421
# 3   5.164806  52.252951  164539.720943
# 4   5.164806  52.252951  164032.344449
#
# [5 rows x 24 columns]

# %%
# Sum weekday bike volume as a proxy for bike traffic volume

# %%
gdf_accidents['total_weekday_volume'] = (
    gdf_accidents['weekday_2017'] +
    gdf_accidents['weekday_2018'] +
    gdf_accidents['weekday_2019'] +
    gdf_accidents['weekday_2020']
)

# Plot relationship between bike volume and total accidents
plt.figure(figsize=(8, 6))
sns.scatterplot(
    x='total_weekday_volume',
    y='total_accidents',
    data=gdf_accidents,
    alpha=0.6
)
plt.title('Relation Between Bike Volume and Accident Count')
plt.xlabel('Total Weekday Bike Volume (2017-2020)')
plt.ylabel('Total Number of Accidents')
plt.tight_layout()
plt.show()

# %%
# Step 1: Identify top hotspot location
top_location = gdf_accidents.groupby('location_code')['total_accidents'].sum().sort_values(ascending=False).head(1).index[0]

# Step 2: Filter to only that location
hotspot_df = gdf_accidents[gdf_accidents['location_code'] == top_location]

# Step 3: Create a DataFrame for plotting severity by weekday in 2020
severity_by_weekday = pd.DataFrame({
    'Fatal': hotspot_df['fatal_accidents'],
    'Injury': hotspot_df['injury_accidents'],
    'Damage Only': hotspot_df['damage_only_accidents'],
    'Weekday Volume 2020': hotspot_df['weekday_2020']
})

# Melt for Seaborn plotting
severity_melted = severity_by_weekday.melt(
    id_vars='Weekday Volume 2020',
    value_vars=['Fatal', 'Injury', 'Damage Only'],
    var_name='Severity',
    value_name='Accident Count'
)

# Create a sorted order for x-axis (descending weekday volume)
volume_order = (
    severity_melted[['Weekday Volume 2020']]
    .drop_duplicates()
    .sort_values(by='Weekday Volume 2020')
)['Weekday Volume 2020']

# Step 4: Plot with Seaborn using order parameter
plt.figure(figsize=(9, 6), facecolor='none')
sns.barplot(
    data=severity_melted,
    x='Weekday Volume 2020',
    y='Accident Count',
    hue='Severity',
    palette='vlag',
    order=volume_order
)

plt.title(f'Severity of Accidents at Hotspot {top_location}', fontsize=14, color='#008000')
plt.xlabel('Bike Volume on Weekdays (2020)', color='#008000')
plt.ylabel('Number of Accidents', color='#008000')
plt.xticks(color='#008000')
plt.yticks(color='#008000')
plt.legend(title='Severity')
plt.gca().set_facecolor('none')
plt.tight_layout()
plt.show()

# %%
df_ams_cc.columns

# %%
#Check for presence of 'shape' column
if 'shape' in df_ams_cc.columns:
    # Extract RD coordinates from LINESTRING
    def extract_rd_coords(linestring):
        match = re.search(r'LINESTRING \(([^,]+)', linestring)
        if match:
            coords = match.group(1).strip().split()
            return float(coords[0]), float(coords[1])
        return None, None

    df_ams_cc[['rd_x', 'rd_y']] = df_ams_cc['shape'].apply(lambda x: pd.Series(extract_rd_coords(x)) if pd.notna(x) else pd.Series([None, None]))

    # Convert to lat/lon using pyproj (EPSG:28992 to EPSG:4326)
    transformer = pyproj.Transformer.from_crs("EPSG:28992", "EPSG:4326", always_xy=True)
    df_ams_cc[['longitude', 'latitude']] = df_ams_cc.apply(lambda row: pd.Series(transformer.transform(row['rd_x'], row['rd_y'])) if pd.notna(row['rd_x']) else pd.Series([None, None]), axis=1)

    # Drop rows without valid coordinates
    df_ams_cc.dropna(subset=['latitude', 'longitude'], inplace=True)

    # Sample for performance
    bike_data_sample = df_ams_cc.head(500)

    # Create map
    map_4 = folium.Map(location=[bike_data_sample['latitude'].mean(), bike_data_sample['longitude'].mean()], zoom_start=12)
    marker_cluster = MarkerCluster().add_to(map_4)

    for _, row in bike_data_sample.iterrows():
        folium.Marker(
         location=[row['latitude'], row['longitude']],
            popup=f"Accident ID: {row.get('accident_id', 'N/A')}"
        ).add_to(marker_cluster)

    map_4
else:
    "The dataset does not contain a 'shape' column. Please upload the correct version."

# %%
map_4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_303caa79ec1d1a3527c4883693a9533e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_303caa79ec1d1a3527c4883693a9533e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_303caa79ec1d1a3527c4883693a9533e = L.map(
#                 &quot;map_303caa79ec1d1a3527c4883693a9533e&quot;,
#                 {
#                     center: [52.36504759306329, 4.887084249063604],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b8e699e18e8cbace40797e04243d198 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4b8e699e18e8cbace40797e04243d198.addTo(map_303caa79ec1d1a3527c4883693a9533e);
#
#
#             var marker_cluster_a1d7c4a2c568cfa17498da2aa18338ec = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_52e4ff0f6d816e93cd02f2e4561303ed = L.marker(
#                 [52.39766034823407, 4.909244485841958],
#                 {
# }
#             ).addTo(marker_cluster_a1d7c4a2c568cfa17498da2aa18338ec);
#
#
#         var popup_f9ca47d14a456191f5436627ee161684 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4345bcaffcf16c55d9b4502d3b1fe127 = $(`&lt;div id=&quot;html_4345bcaffcf16c55d9b4502d3b1fe127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accident ID: 20140010399&lt;/div&gt;`)[0];
#                 popup_f9ca47d14a456191f5436627ee161684.setContent(html_4345bcaffcf16c55d9b4502d3b1fe127);
#
#
#
#         marker_52e4ff0f6d816e93cd02f2e4561303ed.bindPopup(popup_f9ca47d14a456191f5436627ee161684)
#         ;
#
#
#
#
#             var marker_c630e4bd405e1e392d5e345a5f715148 = L.marker(
#                 [52.36232348121334, 4.891819917055534],
#                 {
# }
#             ).addTo(marker_cluster_a1d7c4a2c568cfa17498da2aa18338ec);
#
#
#         var popup_34092fd8340881aa0cfc75b95036194e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ea8433cb7d28d39dbaa0523f7958e98 = $(`&lt;div id=&quot;html_5ea8433cb7d28d39dbaa0523f7958e98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accident ID: 20140011623&lt;/div&gt;`)[0];
#                 popup_34092fd8340881aa0cfc75b95036194e.setContent(html_5ea8433cb7d28d39dbaa0523f7958e98);
#
#
#
#         marker_c630e4bd405e1e392d5e345a5f715148.bindPopup(popup_34092fd8340881aa0cfc75b95036194e)
#         ;
#
#
#
#
#             var marker_b416b7845740ef66c7e01b0ba5948e0b = L.marker(
#                 [52.363257156402135, 4.970084118670077],
#                 {
# }
#             ).addTo(marker_cluster_a1d7c4a2c568cfa17498da2aa18338ec);
#
#
#         var popup_e7722de31bc974e4cc56e274df89a858 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f71d7f84f28f8cc34ff0d7e16c375636 = $(`&lt;div id=&quot;html_f71d7f84f28f8cc34ff0d7e16c375636&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accident ID: 20140011930&lt;/div&gt;`)[0];
#                 popup_e7722de31bc974e4cc56e274df89a858.setContent(html_f71d7f84f28f8cc34ff0d7e16c375636);
#
#
#
#         marker_b416b7845740ef66c7e01b0ba5948e0b.bindPopup(popup_e7722de31bc974e4cc56e274df89a858)
#         ;
#
#
#
#
#             var marker_d75f46f0f1d5f963da07119f641271c8 = L.marker(
#                 [52.391184643677164, 4.881618039147274],
#                 {
# }
#             ).addTo(marker_cluster_a1d7c4a2c568cfa17498da2aa18338ec);
#
#
#         var popup_805c5e125066ca6411c60b9d64ca8513 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_325d7d095d7b6575f05aff2d6bc8587f = $(`&lt;div id=&quot;html_325d7d095d7b6575f05aff2d6bc8587f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accident ID: 20140014189&lt;/div&gt;`)[0];
#                 popup_805c5e125066ca6411c60b9d64ca8513.setContent(html_325d7d095d7b6575f05aff2d6bc8587f);
#
#
#
#         marker_d75f46f0f1d5f963da07119f641271c8.bindPopup(popup
